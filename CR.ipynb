# %% [markdown]
# # LE CR DES GROS CAMTARS

# %%
import csv
import random
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# # Charger le data frame

# %%
df_test = pd.read_csv("data/test.csv")

# %%
df_train = pd.read_csv("data/train.csv")
